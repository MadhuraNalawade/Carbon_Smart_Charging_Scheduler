# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('EV_Grid_Dataset.csv')
df
# Out:
#            Datetime (UTC) Country      Zone name Zone id  \
# 0     2024-01-01 00:00:00   India  Western India   IN-WE
# 1     2024-01-01 01:00:00   India  Western India   IN-WE
# 2     2024-01-01 02:00:00   India  Western India   IN-WE
# 3     2024-01-01 03:00:00   India  Western India   IN-WE
# 4     2024-01-01 04:00:00   India  Western India   IN-WE
# ...                   ...     ...            ...     ...
# 8779  2024-12-31 19:00:00   India  Western India   IN-WE
# 8780  2024-12-31 20:00:00   India  Western India   IN-WE
# 8781  2024-12-31 21:00:00   India  Western India   IN-WE
# 8782  2024-12-31 22:00:00   India  Western India   IN-WE
# 8783  2024-12-31 23:00:00   India  Western India   IN-WE
#
#       Carbon intensity gCO₂eq/kWh (direct)  \
# 0                                   702.48
# 1                                   703.89
# 2                                   704.12
# 3                                   703.69
# 4                                   704.27
# ...                                    ...
# 8779                                686.39
# 8780                                685.06
# 8781                                684.24
# 8782                                684.04
# 8783                                686.04
#
#       Carbon intensity gCO₂eq/kWh (Life cycle)  \
# 0                                       760.73
# 1                                       762.23
# 2                                       762.52
# 3                                       762.15
# 4                                       762.79
# ...                                        ...
# 8779                                    742.67
# 8780                                    741.25
# 8781                                    740.37
# 8782                                    740.15
# 8783                                    742.30
#
#       Carbon-free energy percentage (CFE%)  Renewable energy percentage (RE%)  \
# 0                                     6.76                               2.76
# 1                                     6.57                               2.76
# 2                                     6.54                               2.91
# 3                                     6.60                               3.15
# 4                                     6.52                               3.20
# ...                                    ...                                ...
# 8779                                  9.34                               4.74
# 8780                                  9.51                               4.78
# 8781                                  9.62                               4.82
# 8782                                  9.64                               4.90
# 8783                                  9.38                               4.95
#
#                       Data source  Data estimated    Data estimation method
# 0     Electricity Maps Estimation            True  ESTIMATED_MODE_BREAKDOWN
# 1     Electricity Maps Estimation            True  ESTIMATED_MODE_BREAKDOWN
# 2     Electricity Maps Estimation            True  ESTIMATED_MODE_BREAKDOWN
# 3     Electricity Maps Estimation            True  ESTIMATED_MODE_BREAKDOWN
# 4     Electricity Maps Estimation            True  ESTIMATED_MODE_BREAKDOWN
# ...                           ...             ...                       ...
# 8779  Electricity Maps Estimation            True  ESTIMATED_MODE_BREAKDOWN
# 8780  Electricity Maps Estimation            True  ESTIMATED_MODE_BREAKDOWN
# 8781  Electricity Maps Estimation            True  ESTIMATED_MODE_BREAKDOWN
# 8782  Electricity Maps Estimation            True  ESTIMATED_MODE_BREAKDOWN
# 8783  Electricity Maps Estimation            True  ESTIMATED_MODE_BREAKDOWN
#
# [8784 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Datetime (UTC)                              0
# Country                                     0
# Zone name                                   0
# Zone id                                     0
# Carbon intensity gCO₂eq/kWh (direct)        0
# Carbon intensity gCO₂eq/kWh (Life cycle)    0
# Carbon-free energy percentage (CFE%)        0
# Renewable energy percentage (RE%)           0
# Data source                                 0
# Data estimated                              0
# Data estimation method                      0
# dtype: int64

# %%
df.describe()
# Out:
#        Carbon intensity gCO₂eq/kWh (direct)  \
# count                           8784.000000
# mean                             677.112007
# std                               25.756952
# min                              582.200000
# 25%                              662.140000
# 50%                              680.610000
# 75%                              697.362500
# max                              727.220000
#
#        Carbon intensity gCO₂eq/kWh (Life cycle)  \
# count                               8784.000000
# mean                                 734.999227
# std                                   26.729425
# min                                  635.430000
# 25%                                  719.597500
# 50%                                  738.830000
# 75%                                  755.995000
# max                                  786.170000
#
#        Carbon-free energy percentage (CFE%)  Renewable energy percentage (RE%)
# count                           8784.000000                        8784.000000
# mean                               9.626326                           6.195318
# std                                3.288403                           3.017384
# min                                3.920000                           1.640000
# 25%                                7.070000                           3.880000
# 50%                                9.200000                           5.650000
# 75%                               11.440000                           7.900000
# max                               22.590000                          18.030000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 11 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Datetime (UTC)                            8784 non-null   object
#  1   Country                                   8784 non-null   object
#  2   Zone name                                 8784 non-null   object
#  3   Zone id                                   8784 non-null   object
#  4   Carbon intensity gCO₂eq/kWh (direct)      8784 non-null   float64
#  5   Carbon intensity gCO₂eq/kWh (Life cycle)  8784 non-null   float64
#  6   Carbon-free energy percentage (CFE%)      8784 non-null   float64
#  7   Renewable energy percentage (RE%)         8784 non-null   float64
#  8   Data source                               8784 non-null   object
#  9   Data estimated                            8784 non-null   bool
#  10  Data estimation method                    8784 non-null   object
# dtypes: bool(1), float64(4), object(6)
# memory usage: 695.0+ KB

# %%
df.shape
# Out:
# (8784, 11)

# %%
#Feature Engineering + Data Cleaning
#Rename Columns
df = df.rename(columns={
    "Datetime (UTC)": "timestamp",
    "Carbon intensity gCO₂eq/kWh (direct)": "ci_direct",
    "Carbon intensity gCO₂eq/kWh (Life cycle)": "ci_lifecycle",
    "Carbon-free energy percentage (CFE%)": "cfe_pct",
    "Renewable energy percentage (RE%)": "re_pct",
    "Data estimated": "is_estimated"
})

# %%
# Convert timestamp 
df["timestamp"] = pd.to_datetime(df["timestamp"])

# Sort chronologically 
df = df.sort_values("timestamp").reset_index(drop=True)

# %%
# Data Preprocessing
df = df.drop(columns=[
    "Country",
    "Zone name",
    "Zone id",
    "Data source",
    "Data estimation method",
    "is_estimated"
])

# %%
df.head()
# Out:
#             timestamp  ci_direct  ci_lifecycle  cfe_pct  re_pct
# 0 2024-01-01 00:00:00     702.48        760.73     6.76    2.76
# 1 2024-01-01 01:00:00     703.89        762.23     6.57    2.76
# 2 2024-01-01 02:00:00     704.12        762.52     6.54    2.91
# 3 2024-01-01 03:00:00     703.69        762.15     6.60    3.15
# 4 2024-01-01 04:00:00     704.27        762.79     6.52    3.20

# %%
df.tail()
# Out:
#                timestamp  ci_direct  ci_lifecycle  cfe_pct  re_pct
# 8779 2024-12-31 19:00:00     686.39        742.67     9.34    4.74
# 8780 2024-12-31 20:00:00     685.06        741.25     9.51    4.78
# 8781 2024-12-31 21:00:00     684.24        740.37     9.62    4.82
# 8782 2024-12-31 22:00:00     684.04        740.15     9.64    4.90
# 8783 2024-12-31 23:00:00     686.04        742.30     9.38    4.95

# %%
df["hour"] = df["timestamp"].dt.hour
df["day_of_week"] = df["timestamp"].dt.dayofweek
df["month"] = df["timestamp"].dt.month

# %%
LAGS = [1, 2, 3, 6, 12, 24]

for lag in LAGS:
    df[f"ci_lag_{lag}"] = df["ci_direct"].shift(lag)

# %%
df["ci_roll_6"] = df["ci_direct"].rolling(window=6).mean()
df["ci_roll_24"] = df["ci_direct"].rolling(window=24).mean()

# %%
df = df.dropna().reset_index(drop=True)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,5))
plt.plot(df["timestamp"], df["ci_direct"])
plt.title("Carbon Intensity Over Time")
plt.xlabel("Time")
plt.ylabel("gCO₂/kWh")
plt.grid(True)
plt.show()

# %%
#Visualization carbon intensity hourly
hourly_avg = df.groupby("hour")["ci_direct"].mean()

plt.figure(figsize=(8,4))
plt.plot(hourly_avg.index, hourly_avg.values, marker="o")
plt.title("Average Carbon Intensity by Hour of Day")
plt.xlabel("Hour of Day")
plt.ylabel("Avg gCO₂/kWh")
plt.grid(True)
plt.show()

# %%
dow_avg = df.groupby("day_of_week")["ci_direct"].mean()

plt.figure(figsize=(7,4))
plt.bar(dow_avg.index, dow_avg.values)
plt.title("Average Carbon Intensity by Day of Week")
plt.xlabel("Day (0=Mon, 6=Sun)")
plt.ylabel("Avg gCO₂/kWh")
plt.grid(True)
plt.show()

# %%
monthly_avg = df.groupby("month")["ci_direct"].mean()

plt.figure(figsize=(8,4))
plt.plot(monthly_avg.index, monthly_avg.values, marker="o")
plt.title("Average Carbon Intensity by Month")
plt.xlabel("Month")
plt.ylabel("Avg gCO₂/kWh")
plt.grid(True)
plt.show()

# %%
import seaborn as sns

corr_cols = [
    "ci_direct",
    "hour",
    "day_of_week",
    "month"
]

corr_matrix = df[corr_cols].corr()

plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
 y = df["ci_direct"]


FEATURES = [
    
# Time
    "hour",
    "day_of_week",
    "month",

# Lagged carbon intensity
   "ci_lag_1",
   "ci_lag_2",
   "ci_lag_3",
   "ci_lag_6",
   "ci_lag_12",
   "ci_lag_24",

# Rolling stats
    "ci_roll_6",
    "ci_roll_24"
 ]

X = df[FEATURES]

# %%
#defining training testing manually as shuffling is not allowed for time series data
split = int(len(df) * 0.8)

X_train = X.iloc[:split]
X_test  = X.iloc[split:]

y_train = y.iloc[:split]
y_test  = y.iloc[split:]

# %%
from sklearn.linear_model import LinearRegression
model_lr=LinearRegression()
model_lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr=model_lr.predict(X_test)
y_pred_lr
# Out:
# array([689.19457132, 687.59966547, 688.2543468 , ..., 683.45292181,
#        684.88754657, 686.03668168])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

mae = mean_absolute_error(y_test, y_pred_lr)
rmse = np.sqrt(mean_squared_error(y_test, y_pred_lr))
r2 = r2_score(y_test, y_pred_lr)

print("Linear Regression MAE:", mae)
print("Linear Regression RMSE:", rmse)
print("Linear Regression R²:", r2)
# Out:
# Linear Regression MAE: 2.648958570211784
# Linear Regression RMSE: 3.568154825834205
# Linear Regression R²: 0.9330527119011763

# %%
mse=mean_squared_error(y_test, y_pred_lr)
print("MSE(Mean Squared Error):", mse)
# Out:
# MSE(Mean Squared Error): 12.731728861123925

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,4))
plt.plot(y_test.values, label="Actual")
plt.plot(y_pred_lr, label="Predicted")
plt.legend()
plt.title("Actual vs Predicted Carbon Intensity")
plt.show()

# %%
residuals = y_test.values - y_pred_lr

plt.figure(figsize=(14,4))
plt.plot(residuals)
plt.axhline(0, linestyle="--")
plt.title("Residuals Over Time (Linear Regression)")
plt.xlabel("Time")
plt.ylabel("Prediction Error (gCO₂/kWh)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred_lr, alpha=0.6)
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--"
)
plt.xlabel("Actual Carbon Intensity")
plt.ylabel("Predicted Carbon Intensity")
plt.title("Actual vs Predicted Scatter (Linear Regression)")
plt.grid(True)
plt.show()

# %%
import joblib

joblib.dump(model_lr, "carbon_intensity_model.pkl")
# Out:
# ['carbon_intensity_model.pkl']
